# %% [markdown]
# # Descripció
#
# Familiaritza't amb les tècniques d'exploració de les dades mitjantçant la estructura de dades, Dataframe amb la llibreria Pandas.

# %% [markdown]
# ## <span style='color:Blue'>Nivell 1</span>

# %% [markdown]
# ### Exercici 1
#
# Descarrega el data set Airlines Delay: Airline on-time statistics and delay causes i carrega’l a un pandas Dataframe. Explora les dades que conté, i queda’t únicament amb les columnes que consideris rellevants.

# %%
# Importació de la llibreria
import pandas as pd

# %%
# Carregar les dades
df = pd.read_csv("dades/DelayedFlights.csv")

# %% [markdown]
# Explicació del df (extreta de https://www.kaggle.com/adveros/flight-delay-eda-exploratory-data-analysis)
#
# This dataset is composed by the following variables:
#
#    **Year** 2008
#
#    **Month** 1-12
#
#    **DayofMonth** 1-31
#
#    **DayOfWeek** 1 (Monday) - 7 (Sunday)
#
#    **DepTime** actual departure time (local, hhmm)
#
#    **CRSDepTime** scheduled departure time (local, hhmm)
#
#    **ArrTime** actual arrival time (local, hhmm)
#
#    **CRSArrTime** scheduled arrival time (local, hhmm)
#
#    **UniqueCarrier** unique carrier code
#
#    **FlightNum** flight number
#
#    **TailNum** plane tail number: aircraft registration, unique aircraft identifier
#
#    **ActualElapsedTime** in minutes
#
#    **CRSElapsedTime** in minutes
#
#    **AirTime** in minutes
#
#    **ArrDelay** arrival delay, in minutes: A flight is counted as "on time" if it operated less than 15 minutes later the scheduled time shown in the carriers' Computerized Reservations Systems (CRS)
#
#    **DepDelay** departure delay, in minutes
#
#    **Origin** origin IATA airport code
#
#    **Dest** destination IATA airport code
#
#    **Distance** in miles
#
#    **TaxiIn** taxi in time, in minutes
#
#    **TaxiOut** taxi out time in minutes
#
#    **Cancelled** *was the flight cancelled
#
#    **CancellationCode** reason for cancellation (A = carrier, B = weather, C = NAS, D = security)
#
#    **Diverted** 1 = yes, 0 = no
#
#    **CarrierDelay** in minutes: Carrier delay is within the control of the air carrier. Examples of occurrences that may determine carrier delay are: aircraft cleaning, aircraft damage, awaiting the arrival of connecting passengers or crew, baggage, bird strike, cargo loading, catering, computer, outage-carrier equipment, crew legality (pilot or attendant rest), damage by hazardous goods, engineering inspection, fueling, handling disabled passengers, late crew, lavatory servicing, maintenance, oversales, potable water servicing, removal of unruly passenger, slow boarding or seating, stowing carry-on baggage, weight and balance delays.
#
#    **WeatherDelay** in minutes: Weather delay is caused by extreme or hazardous weather conditions that are forecasted or manifest themselves on point of departure, enroute, or on point of arrival.
#
#   **NASDelay** in minutes: Delay that is within the control of the National Airspace System (NAS) may include: non-extreme weather conditions, airport operations, heavy traffic volume, air traffic control, etc.
#
#   **SecurityDelay** in minutes: Security delay is caused by evacuation of a terminal or concourse, re-boarding of aircraft because of security breach, inoperative screening equipment and/or long lines in excess of 29 minutes at screening areas.
#
#   **LateAircraftDelay** in minutes: Arrival delay at an airport due to the late arrival of the same aircraft at a previous airport. The ripple effect of an earlier delay at downstream airports is referred to as delay propagation.

# %%
# Mostrar el 5 primers registres -> head() [cap]
# afegint un valor com a paràmetre es pot especificar la quantitat de registres a mostrar 
df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2211.0        2225            WN  ...     4.0     8.0          0
# 1   1002.0        1000            WN  ...     5.0    10.0          0
# 2    804.0         750            WN  ...     3.0    17.0          0
# 3   1959.0        1925            WN  ...     3.0    10.0          0
# 4   2121.0        2110            WN  ...     4.0    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
# Mostrar el 8 primers registres -> df.head(8)
df.head(8)
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
# 5           6  2008      1           3          4   1937.0        1830
# 6          10  2008      1           3          4    706.0         700
# 7          11  2008      1           3          4   1644.0        1510
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2211.0        2225            WN  ...     4.0     8.0          0
# 1   1002.0        1000            WN  ...     5.0    10.0          0
# 2    804.0         750            WN  ...     3.0    17.0          0
# ...

# %%
# Mostrar el últim 5 registres -> tail() [cua]
# És igual que head(), però des del final 
df.tail()
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
#          ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 1936753   1617.0        1552            DL  ...     9.0    18.0          0
# 1936754    904.0         749            DL  ...    15.0    34.0          0
# 1936755   1149.0        1010            DL  ...     8.0    32.0          0
# 1936756   1446.0        1437            DL  ...    13.0    13.0          0
# 1936757   1413.0        1418            DL  ...     8.0    11.0          0
#
# ...

# %%
# Mostrar qualsevol fragment del df
# S'utilitza sintaxi slicing 
df[10:20]

# Per tant df[0:10] equival a df.head()
# Out:
#     Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 10          17  2008      1           3          4    754.0         745
# 11          18  2008      1           3          4   1323.0        1255
# 12          19  2008      1           3          4   1416.0        1325
# 13          21  2008      1           3          4   1657.0        1625
# 14          22  2008      1           3          4   1900.0        1840
# 15          23  2008      1           3          4   1039.0        1030
# 16          25  2008      1           3          4   1520.0        1455
# 17          26  2008      1           3          4   1422.0        1255
# 18          27  2008      1           3          4   1954.0        1925
# 19          30  2008      1           3          4   2107.0        1945
#
#     ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 10    940.0         955            WN  ...     5.0    16.0          0
# ...

# %%
# Modificar el df per a que les dades perdin l'ordre -> sample(frac = x) [x = 1 equival a 100% dels registres]
# Serveix per a tenir una visió més general.
df.sample(frac = 1)

# Per a guardar aquest df desordenat l'hauriem de guardar en una nova variable
# df_sample = df.sample(frac = 1)
# Però ara no ho necessitem
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 220785       702069  2008      2           1          5   1455.0        1410
# 612040      1927948  2008      4          14          1   2225.0        2215
# 922881      3102857  2008      6          12          4   1940.0        1855
# 1519955     5361420  2008      9          20          6    735.0         710
# 733978      2409209  2008      5           9          5   1137.0        1130
# ...             ...   ...    ...         ...        ...      ...         ...
# 922257      3101021  2008      6          24          2   1927.0        1715
# 430640      1331747  2008      3           8          6   1525.0        1315
# 1425758     4833576  2008      8           8          5   1437.0        1423
# 751695      2458116  2008      5          23          5   1743.0        1645
# 282477       901060  2008      2          23          6   1542.0         715
#
# ...

# %%
# Mostrar nom de columnes -> columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
# Mostrar typus de les dades en les columnes
df.dtypes
# Out:
# Unnamed: 0             int64
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
# la informació mostrada com array, no com a taula
df.values
# Out:
# array([[0, 2008, 1, ..., nan, nan, nan],
#        [1, 2008, 1, ..., nan, nan, nan],
#        [2, 2008, 1, ..., nan, nan, nan],
#        ...,
#        [7009718, 2008, 12, ..., 19.0, 0.0, 79.0],
#        [7009726, 2008, 12, ..., nan, nan, nan],
#        [7009727, 2008, 12, ..., nan, nan, nan]], dtype=object)

# %%
# Mostrar valors d'una columna
# sintaxi 1
df["ArrTime"].head()
# Out:
# 0    2211.0
# 1    1002.0
# 2     804.0
# 3    1959.0
# 4    2121.0
# Name: ArrTime, dtype: float64

# %%
# sintaxi 2
df.ArrTime.head()
# Out:
# 0    2211.0
# 1    1002.0
# 2     804.0
# 3    1959.0
# 4    2121.0
# Name: ArrTime, dtype: float64

# %%
# Els 20 primers orígens dels vols
df.Origin.head(3)
# Out:
# 0    IAD
# 1    IAD
# 2    IND
# Name: Origin, dtype: object

# %%
# Mostrar informació segons una condició booleana

# Exemple : les dades del segons semestre de cada any
df[df["Month"] > 6].head()
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 1083153     3604177  2008      7           2          3   1610.0        1555
# 1083154     3604181  2008      7           2          3   1329.0        1310
# 1083155     3604193  2008      7           2          3   2156.0        2140
# 1083156     3604197  2008      7           2          3   1829.0        1820
# 1083157     3604200  2008      7           2          3    912.0         900
#
#          ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 1083153   1733.0        1720            WN  ...     3.0    10.0          0
# 1083154   1446.0        1435            WN  ...     5.0     9.0          0
# 1083155   2311.0        2250            WN  ...     6.0    17.0          0
# 1083156   1954.0        1945            WN  ...     3.0    13.0          0
# 1083157   1035.0        1025            WN  ...     5.0    12.0          0
#
# ...

# %%
# Exemple : les dades dels vols que surten d'Atlanta -> origen = ATL
df[df["Origin"] == "ATL"].head()
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 33678      104019  2008      1          20          7   1403.0        1330
# 35013      108680  2008      1           3          4   1429.0        1340
# 35165      109189  2008      1          31          4   1217.0        1210
# 35225      109405  2008      1          28          1   1229.0        1210
# 35511      110375  2008      1          19          6   1241.0        1215
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 33678   1625.0        1608            XE  ...     6.0    32.0          0
# 35013   1531.0        1500            XE  ...     7.0    11.0          0
# 35165   1511.0        1335            XE  ...    21.0    60.0          0
# 35225   1343.0        1335            XE  ...     6.0    20.0          0
# 35511   1735.0        1437            XE  ...    12.0   178.0          0
#
#        CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
# Exemple : les dades dels vols que surten d'Atlanta al gener -> origen == ATL i Month == 1
# Cada condició ha de quedar entre parèntesi
df[(df["Origin"] == "ATL") & (df["Month"] == 1)].head()
# Out:
#        Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 33678      104019  2008      1          20          7   1403.0        1330
# 35013      108680  2008      1           3          4   1429.0        1340
# 35165      109189  2008      1          31          4   1217.0        1210
# 35225      109405  2008      1          28          1   1229.0        1210
# 35511      110375  2008      1          19          6   1241.0        1215
#
#        ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 33678   1625.0        1608            XE  ...     6.0    32.0          0
# 35013   1531.0        1500            XE  ...     7.0    11.0          0
# 35165   1511.0        1335            XE  ...    21.0    60.0          0
# 35225   1343.0        1335            XE  ...     6.0    20.0          0
# 35511   1735.0        1437            XE  ...    12.0   178.0          0
#
#        CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %%
# També es poden demanar dades en un conjunt, que s'indica com una llista

# Exemple : vols que han sortit de Houston i Atlanta
df[df.Origin.isin(["HOU", "ATL"])]
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 2053           3272  2008      1           4          5   1603.0        1550
# 2054           3278  2008      1           4          5    823.0         805
# 2055           3282  2008      1           4          5   2013.0        1950
# 2056           3305  2008      1           4          5   1214.0        1200
# 2057           3314  2008      1           4          5   1658.0        1630
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936741     7009655  2008     12          13          6    955.0         934
# 1936743     7009660  2008     12          13          6   1053.0        1000
# 1936745     7009666  2008     12          13          6   1025.0         950
# 1936751     7009705  2008     12          13          6    921.0         830
# 1936755     7009718  2008     12          13          6   1007.0         847
#
# ...

# %%
# Quants registres tenen la columna ArrDelay buida?
len(df[pd.isna(df["ArrDelay"])])
# Out:
# 8387

# %% [markdown]
# ### Transformacions

# %%
# Crear nova columna "HoursDelay com a transformació"
df["HoursDelay"] = round(df["ArrDelay"] / 60)
df["HoursDelay"].head()
# Out:
# 0   -0.0
# 1    0.0
# 2    0.0
# 3    1.0
# 4    0.0
# Name: HoursDelay, dtype: float64

# %%
# Eliminar columna
del(df["HoursDelay"])
# Això donarà error perquè la columna ja no existeix
# df["HoursDelay"].head()

# %%
# Eliminar diverses columnes al mateix temps
# Cal especicificar com a llista els noms de les columnes a eliminar
# També cal especificar l'eix: axis = 1 -> columnes
df.drop(["Diverted", "Cancelled", "Year"], axis = 1)

# Nota : així com està ho executa però no ho guarda
# Out:
#          Unnamed: 0  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0      1           3          4   2003.0        1955
# 1                 1      1           3          4    754.0         735
# 2                 2      1           3          4    628.0         620
# 3                 4      1           3          4   1829.0        1755
# 4                 5      1           3          4   1940.0        1915
# ...             ...    ...         ...        ...      ...         ...
# 1936753     7009710     12          13          6   1250.0        1220
# 1936754     7009717     12          13          6    657.0         600
# 1936755     7009718     12          13          6   1007.0         847
# 1936756     7009726     12          13          6   1251.0        1240
# 1936757     7009727     12          13          6   1110.0        1103
#
#          ArrTime  CRSArrTime UniqueCarrier  FlightNum  ... Dest  Distance  \
# ...

# %%
# Per a que ho guardi:
df = df.drop(["Diverted", "Cancelled", "Year"], axis = 1)

# %%
# Així també ho faria, sense que calgui igualar
df.drop(["CancellationCode"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0           0      1           3          4   2003.0        1955   2211.0
# 1           1      1           3          4    754.0         735   1002.0
# 2           2      1           3          4    628.0         620    804.0
# 3           4      1           3          4   1829.0        1755   1959.0
# 4           5      1           3          4   1940.0        1915   2121.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... Origin  Dest  Distance  TaxiIn  \
# 0        2225            WN        335  ...    IAD   TPA       810     4.0
# 1        1000            WN       3231  ...    IAD   TPA       810     5.0
# 2         750            WN        448  ...    IND   BWI       515     3.0
# 3        1925            WN       3920  ...    IND   BWI       515     3.0
# 4        2110            WN        378  ...    IND   JAX       688     4.0
#
#    TaxiOut  CarrierDelay WeatherDelay NASDelay  SecurityDelay  \
# ...

# %%
# Eliminar una filera, p.e. la primera
df.drop(0)
# Out:
#          Unnamed: 0  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 1                 1      1           3          4    754.0         735
# 2                 2      1           3          4    628.0         620
# 3                 4      1           3          4   1829.0        1755
# 4                 5      1           3          4   1940.0        1915
# 5                 6      1           3          4   1937.0        1830
# ...             ...    ...         ...        ...      ...         ...
# 1936753     7009710     12          13          6   1250.0        1220
# 1936754     7009717     12          13          6    657.0         600
# 1936755     7009718     12          13          6   1007.0         847
# 1936756     7009726     12          13          6   1251.0        1240
# 1936757     7009727     12          13          6   1110.0        1103
#
#          ArrTime  CRSArrTime UniqueCarrier  FlightNum  ... Origin  Dest  \
# ...

# %%
# Eliminar un rang de columnes, p.e. les 100 primeres
df.drop(range(0,100))

# Això no queda guardat. Caldria fer
# df.drop(range(0,100), inplace = True), o
# df = df.drop(range(0,100))
# Out:
#          Unnamed: 0  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 100             142      1           3          4   1556.0        1455
# 101             145      1           3          4   1540.0        1525
# 102             147      1           3          4   1228.0        1200
# 103             148      1           3          4   2047.0        2005
# 104             149      1           3          4   2158.0        2120
# ...             ...    ...         ...        ...      ...         ...
# 1936753     7009710     12          13          6   1250.0        1220
# 1936754     7009717     12          13          6    657.0         600
# 1936755     7009718     12          13          6   1007.0         847
# 1936756     7009726     12          13          6   1251.0        1240
# 1936757     7009727     12          13          6   1110.0        1103
#
#          ArrTime  CRSArrTime UniqueCarrier  FlightNum  ... Origin  Dest  \
# ...

# %%
# Crear nou dt a partir de l'existent
df_ATL = df[df.Origin == "ATL"]
df_HOU = df[df.Origin == "HOU"]

# %%
df_ATL.head()
# Out:
#        Unnamed: 0  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 33678      104019      1          20          7   1403.0        1330   1625.0
# 35013      108680      1           3          4   1429.0        1340   1531.0
# 35165      109189      1          31          4   1217.0        1210   1511.0
# 35225      109405      1          28          1   1229.0        1210   1343.0
# 35511      110375      1          19          6   1241.0        1215   1735.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... Origin  Dest  Distance  \
# 33678        1608            XE       1284  ...    ATL   EWR       745
# 35013        1500            XE       2112  ...    ATL   IAH       689
# 35165        1335            XE       2023  ...    ATL   IAH       689
# 35225        1335            XE       2349  ...    ATL   IAH       689
# 35511        1437            XE       1284  ...    ATL   EWR       745
#
# ...

# %%
# Barrejar df, si tenen la mateixa estructura
df_ATL_HOU = df_ATL.append(df_HOU)

# %%
df_ATL_HOU.Origin
# Out:
# 33678      ATL
# 35013      ATL
# 35165      ATL
# 35225      ATL
# 35511      ATL
#           ...
# 1933530    HOU
# 1934119    HOU
# 1934989    HOU
# 1935477    HOU
# 1936464    HOU
# Name: Origin, Length: 151252, dtype: object

# %% [markdown]
# ### groupby

# %%
# Tres paràmetres:
#   Nom de la columna
#   Nom de columna
# funció

df.groupby(by = "DayOfWeek")["ArrDelay"].max()
# Això dona el màxim endarreriment per dia de la setmana
# groupby agrupa per cada dia de la setmana (columna 1), l'endarreriment (columna 2) i li aplica una funció (el màxim)

# altres funcions:
# min()
# mean() -> mitjana
# count() -> quants
# describe() --> resum estadístic
# Out:
# DayOfWeek
# 1    1583.0
# 2    1951.0
# 3    1510.0
# 4    2453.0
# 5    1707.0
# 6    1525.0
# 7    2461.0
# Name: ArrDelay, dtype: float64

# %%
df.groupby(by = "DayOfWeek")["ArrDelay"].mean()
# Out:
# DayOfWeek
# 1    41.731356
# 2    43.806679
# 3    40.438229
# 4    41.071599
# 5    43.493618
# 6    39.393828
# 7    44.697413
# Name: ArrDelay, dtype: float64

# %%
# Un altre exemple
df.groupby(by = "DayOfWeek")["ArrDelay", "DepDelay"].mean()
# Out:
# C:\Users\Gran\AppData\Local\Temp/ipykernel_13608/1949532019.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by = "DayOfWeek")["ArrDelay", "DepDelay"].mean()
#             ArrDelay   DepDelay
# DayOfWeek
# 1          41.731356  43.227633
# 2          43.806679  44.075603
# 3          40.438229  41.429611
# 4          41.071599  41.676591
# 5          43.493618  44.016943
# 6          39.393828  41.480063
# 7          44.697413  45.859422

# %%
# rang per dia de la setmana
df.groupby(by = "DayOfWeek")["ArrDelay"].max()-df.groupby(by = "DayOfWeek")["ArrDelay"].min()
# Out:
# DayOfWeek
# 1    1652.0
# 2    2010.0
# 3    1580.0
# 4    2562.0
# 5    1764.0
# 6    1585.0
# 7    2527.0
# Name: ArrDelay, dtype: float64

# %%
dfATLHOU = df[df.Origin.isin(["HOU", "ATL"])]

# %%
dfATLHOU.groupby(by = ["DayOfWeek", "Origin"])["ArrDelay"].mean()
# Out:
# DayOfWeek  Origin
# 1          ATL       34.380620
#            HOU       30.081725
# 2          ATL       40.840086
#            HOU       37.512793
# 3          ATL       40.075684
#            HOU       34.033631
# 4          ATL       39.120478
#            HOU       36.010678
# 5          ATL       43.907486
#            HOU       31.741449
# 6          ATL       40.684830
#            HOU       30.105621
# 7          ATL       45.877264
#            HOU       28.303064
# Name: ArrDelay, dtype: float64

# %% [markdown]
# ### Casos duplicats

# %%
dfclean = df.drop_duplicates()

# %%
# "DayofMonth" són els dies del mes, per tant el màxim són 31
dfclean.drop_duplicates(subset = "DayofMonth")
# Out:
#        Unnamed: 0  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0               0      1           3          4   2003.0        1955   2211.0
# 1661         2367      1           4          5   2003.0        1845   2207.0
# 3409         5805      1           5          6   2001.0        1845   2150.0
# 4914         8614      1           6          7   1852.0        1845   2044.0
# 6752        11844      1           7          1    911.0         905   1422.0
# 7746        15281      1           8          2   1456.0        1435   1727.0
# 8630        18718      1           9          3    755.0         655   1021.0
# 9289        22151      1          10          4   2004.0        1845   2154.0
# 10139       25588      1          11          5   1911.0        1845   2102.0
# 10962       29027      1          12          6    906.0         900   1422.0
# 11269       31810      1          13          7   2016.0        1950   2209.0
# ...

# %%
# Eliminar fileres quan falta alguna dada 
# df.dropna()
# Esborra la filera sensera

# %%
# Es pot fixar un mímin de columnes amb dades
df. dropna(thresh = 25)
# Out:
#          Unnamed: 0  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 3                 4      1           3          4   1829.0        1755
# 5                 6      1           3          4   1937.0        1830
# 7                11      1           3          4   1644.0        1510
# 9                16      1           3          4   1452.0        1425
# 11               18      1           3          4   1323.0        1255
# ...             ...    ...         ...        ...      ...         ...
# 1936751     7009705     12          13          6    921.0         830
# 1936752     7009709     12          13          6   1552.0        1520
# 1936753     7009710     12          13          6   1250.0        1220
# 1936754     7009717     12          13          6    657.0         600
# 1936755     7009718     12          13          6   1007.0         847
#
#          ArrTime  CRSArrTime UniqueCarrier  FlightNum  ... Origin  Dest  \
# ...

# %%
# Fixar el màxim de dos valors faltants
df.dropna(thresh = len(df.columns)-2)
# Out:
#          Unnamed: 0  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 3                 4      1           3          4   1829.0        1755
# 5                 6      1           3          4   1937.0        1830
# 7                11      1           3          4   1644.0        1510
# 9                16      1           3          4   1452.0        1425
# 11               18      1           3          4   1323.0        1255
# ...             ...    ...         ...        ...      ...         ...
# 1936751     7009705     12          13          6    921.0         830
# 1936752     7009709     12          13          6   1552.0        1520
# 1936753     7009710     12          13          6   1250.0        1220
# 1936754     7009717     12          13          6    657.0         600
# 1936755     7009718     12          13          6   1007.0         847
#
#          ArrTime  CRSArrTime UniqueCarrier  FlightNum  ... Origin  Dest  \
# ...

# %%
# Treure els nuls d'una columna en concret
df.dropna(subset = ["CarrierDelay"])
# Out:
#          Unnamed: 0  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 3                 4      1           3          4   1829.0        1755
# 5                 6      1           3          4   1937.0        1830
# 7                11      1           3          4   1644.0        1510
# 9                16      1           3          4   1452.0        1425
# 11               18      1           3          4   1323.0        1255
# ...             ...    ...         ...        ...      ...         ...
# 1936751     7009705     12          13          6    921.0         830
# 1936752     7009709     12          13          6   1552.0        1520
# 1936753     7009710     12          13          6   1250.0        1220
# 1936754     7009717     12          13          6    657.0         600
# 1936755     7009718     12          13          6   1007.0         847
#
#          ArrTime  CRSArrTime UniqueCarrier  FlightNum  ... Origin  Dest  \
# ...

# %%
import numpy as np
np.median(df["ArrTime"])
# Out:
# nan

# %% [markdown]
# ### Exercici 2
#
# Fes un informe complet del data set:.
#
#     Resumeix estadísticament les columnes d’interès
#     Troba quantes dades faltants hi ha per columna
#     Crea columnes noves (velocitat mitjana del vol, si ha arribat tard o no...)
#     Taula de les aerolínies amb més endarreriments acumulats
#     Quins són els vols més llargs? I els més endarrerits?
#     Etc.

# %% [markdown]
# ### Exercici 3
#
# Exporta el data set net i amb les noves columnes a Excel.
